# %%
import pandas as pd
import numpy as np
import re
from bs4 import BeautifulSoup

# %%
df = pd.read_csv('./feats_merge_train.csv')

# %%
df['topics'].head(5)
# Out:
# 0    asteroid,asteroids,challenge,earth,space,u.s.,...
# 1    apps and software,google,open source,opn pledg...
# 2        entertainment,nfl,nfl draft,sports,television
# 3                      sports,video,videos,watercooler
# 4    entertainment,instagram,instagram video,nfl,sp...
# Name: topics, dtype: object

# %%
from nltk.stem.porter import PorterStemmer

topics = df['topics'].values

# %%
topics
# Out:
# array(['asteroid,asteroids,challenge,earth,space,u.s.,world',
#        'apps and software,google,open source,opn pledge,patent lawsuit theater,software patents,tech,u.s.',
#        'entertainment,nfl,nfl draft,sports,television', ...,
#        'food,hot dogs,humor,photography,watercooler',
#        'business,marissa mayer,media,stocks,yahoo',
#        'austin,business,curiocity,small business,startups'], dtype=object)

# %%
porter = PorterStemmer()
stemmed_topics = []
for topic in topics:
    words = str(topic).split(',')
    stemmed_topics.append([porter.stem(word) for word in words])

# %%
stemmed_topics
# Out:
# [['asteroid', 'asteroid', 'challeng', 'earth', 'space', 'u.s.', 'world'],
#  ['apps and softwar',
#   'googl',
#   'open sourc',
#   'opn pledg',
#   'patent lawsuit theat',
#   'software pat',
#   'tech',
#   'u.s.'],
#  ['entertain', 'nfl', 'nfl draft', 'sport', 'televis'],
#  ['sport', 'video', 'video', 'watercool'],
#  ['entertain', 'instagram', 'instagram video', 'nfl', 'sport'],
#  ['govern',
#   'internet',
#   'internet service provid',
#   'lobbi',
#   'lobbyist',
#   'mobil',
#   'polit',
#   'startup',
#   'u.s.',
#   'world'],
#  ['entertain', 'funni', 'iggy azalea', 'music', 'parodi', 'video', 'video'],
#  ['bill cosbi', 'entertain', 'televis'],
#  ['apps and softwar',
#   'gadget',
#   'mobil',
#   'tech',
#   'vending machin',
#   'vending machin'],
#  ['busi', 'media', 'the new york tim', 'paywal'],
#  ['astronomi', 'moon', 'saturn', 'space', 'world'],
#  ['humor', 'mad men', 'photographi', 'televis', 'watercool'],
#  ['apps and softwar', 'nevada', 'tech', 'u.s.'],
#  ['appl', 'busi', 'dev & design', 'steve job', 'u.s.'],
#  ['entertain', 'soccer', 'sport', 'uswnt', "women's world cup", 'world cup'],
#  ['air safeti', 'airplan', 'travel', 'aviat', 'travel & leisur', 'world'],
#  ['busi', 'recal'],
#  ['food', 'video', 'video', 'viral video', 'watercool', 'wine'],
#  ['busi', 'comcast', 'net neutrality ', 'u.s.'],
#  ['busi', 'googl', 'larry pag', 'stock'],
#  ['appl', 'surveil', 'transpar', 'transparency report', 'u.s.', 'world'],
#  ['entertain', 'game of thron', 'televis', 'ugc'],
#  ['chris hadfield', 'easter', 'gadget', 'space', 'photographi', 'world'],
#  ['ukraine ', 'world'],
#  ['alex trebek',
#   'convers',
#   'entertain',
#   'jeopardi',
#   'mustach',
#   'televis',
#   'watercool'],
#  ['busi', 'job board', 'job', 'media', 'pricelin', 'tech'],
#  ['amc', 'entertain', 'humor', 'mad men', 'nowthisnew', 'televis'],
#  ['apps and softwar', 'facebook', 'instagram', 'photo shar', 'social media'],
#  ['ada lovelac',
#   'apps and softwar',
#   'arduino',
#   'dev & design',
#   'educ',
#   'empow',
#   'family & par',
#   'raspberry pi',
#   'stem',
#   'travel',
#   'travel & leisur',
#   'u.s.',
#   'world',
#   'women in tech',
#   'work & play'],
#  ['malala', 'malala yousafzai', 'nobel', 'world'],
#  ['danc', 'religion', 'video', 'video', 'watercool'],
#  ['at&t;',
#   'credo mobil',
#   'surveil',
#   'transpar',
#   'transparency report',
#   'u.s.',
#   'world',
#   'verizon'],
#  ['gadget',
#   'health & fit',
#   'medical sci',
#   'medical technolog',
#   'robot',
#   'tech'],
#  ['data visu', 'polit', 'u.s. sen', 'u.s. sen', 'u.s.', 'world'],
#  ['band', 'funni', 'humor', 'music', 'watercool'],
#  ['adida',
#   'busi',
#   'market',
#   'matt bonn',
#   'nba',
#   'new bal',
#   'sport',
#   'twitter'],
#  ['a/b test', 'busi', 'market', 'metrics that matt', 'online market'],
#  ['climat', 'u.s.', 'world', 'wall street'],
#  ['abc new',
#   'australia',
#   'australia journalist',
#   'malaysia airlines flight 17 in ukrain',
#   'malaysia airlines flight 17 in ukrain',
#   'mh17 passeng',
#   'world'],
#  ['parent', 'cute kid', 'gangnam styl', 'psi', 'video', 'video', 'watercool'],
#  ['entertain', 'instagram', 'music', 'rihanna'],
#  ['busi',
#   'dev & design',
#   'dreamforc',
#   'marc benioff',
#   'marissa may',
#   'salesforc',
#   'work & play',
#   'yahoo'],
#  ['entertain', 'nba', 'sport'],
#  ['end of 2013', 'photographi', 'u.s.', 'world'],
#  ['entertain', 'media', 'music', 'u.s.'],
#  ['3d print',
#   'apps and softwar',
#   'busi',
#   'fashion',
#   'dev & design',
#   'gadget',
#   'mashable must read',
#   'lifestyl',
#   'makerbot',
#   'tech',
#   'work & play'],
#  ['basebal', 'entertain', 'mlb', 'sport'],
#  ['american apparel', 'busi', 'market', 'olymp'],
#  ['dev & design',
#   'gadget',
#   'gesture control',
#   'leap mot',
#   'leap motion control',
#   'tech'],
#  ['batman', 'batman arkham knight', 'entertain', 'game', 'rocksteady gam'],
#  ['galaxy gear', 'mobil', 'samsung', 'smartwatch', 'tech'],
#  ['american airlin',
#   'apps and softwar',
#   'game',
#   'hack',
#   'lizard squad',
#   'playstat',
#   'smedley',
#   'soni',
#   'twitter',
#   'u.s.',
#   'world'],
#  ['data privaci', 'european union', 'googl', 'world'],
#  ['celebr',
#   'convers',
#   'entertain',
#   'movi',
#   'jaden smith',
#   'media',
#   'watercool',
#   'weird',
#   'willow smith'],
#  ['al qaeda', 'terror', 'world', 'yemen'],
#  ['sex & lov', 'lifestyl', 'match.com', 'mobil', 'online d'],
#  ['contributor', 'gun viol', 'gun', 'poverti', 'u.s.', 'us & world', 'world'],
#  ['live stream', 'puppycam', 'social good', 'world', 'veterans servic'],
#  ['apps and softwar', 'dev & design', 'gadget', 'tech'],
#  ['ferri', 'south korea', 'south korea ferri', 'world'],
#  ["asperger'",
#   'autism',
#   'disabl',
#   'entertain',
#   'movi',
#   'health & fit',
#   'mashable must read',
#   'medicin',
#   'mental health',
#   'pop cultur',
#   'social good',
#   'televis'],
#  ['chart of the day', 'social media', 'twitter', 'world'],
#  ['advertis', 'busi', 'convers', 'market', 'secret', 'tumblr'],
#  ['entertain', 'market', 'nba', 'sport'],
#  ['antarctica', 'australia', 'live fe', 'solar eclips', 'space', 'world'],
#  ['contributor', 'entertain', 'netflix', 'stream', 'televis'],
#  ['busi', 'live chat', 'startup', 'yec'],
#  ['polit', 'twitter', 'world'],
#  ['app', 'apps and softwar', 'mobil', 'mobile app', 'tech', 'video', 'climat'],
#  ['facebook', 'myspac', 'watercool'],
#  ['busi', 'small busi', 'startup', 'work & play'],
#  ['mashable must read', 'mudslid', 'u.s.', 'world'],
#  ['cyberterror',
#   'cyberwar',
#   'department of homeland secur',
#   'north korea',
#   'pentagon',
#   'polit',
#   'u.s.',
#   'world'],
#  ['amazon', 'android', 'app', 'apps and softwar', 'mobil', 'tech'],
#  ['apps and softwar',
#   'busi',
#   'dev & design',
#   'features roundup',
#   'gadget',
#   'lifestyl',
#   'market',
#   'mobil',
#   'ostrich pillow light',
#   'social',
#   'tech',
#   'travel',
#   'travel & leisur',
#   'twitter',
#   'work & play'],
#  ['comic-con',
#   'cosplay',
#   'cosplay',
#   'costum',
#   'entertain',
#   'movi',
#   'game',
#   'nycc',
#   'photographi',
#   'televis'],
#  ['heml.i', 'hemli', 'mobil', 'peter sund', 'pirate bay', 'tech'],
#  ['comic', 'game of thron', 'humor', 'televis', 'watercool'],
#  ['entertain',
#   'kickstart',
#   'money',
#   'music',
#   'new york c',
#   'opera',
#   'travel',
#   'travel & leisur',
#   'work & play'],
#  ['europ', 'polit', 'uk', 'world'],
#  ['app',
#   'apps and softwar',
#   'lifestyl',
#   'summer',
#   'travel',
#   'travel & leisur'],
#  ['apps and softwar',
#   'gadget',
#   'kickstart',
#   'mobil',
#   'pebbl',
#   'runkeep',
#   'tech'],
#  ['apps and softwar',
#   'cern',
#   'dev & design',
#   'tech',
#   'tim berners-le',
#   'world',
#   'world wide web'],
#  ['hdr',
#   'travel',
#   'travel & leisur',
#   'video',
#   'video',
#   'viral video',
#   'warsaw',
#   'watercool'],
#  ['fossil', 'height', 'penguin', 'world'],
#  ['advertis', 'busi', 'earn', 'facebook', 'facebooks ad'],
#  ['advertis', 'busi', 'gaff', 'hyundai'],
#  ['cover song', 'game of thron', 'video', 'video', 'viral video', 'watercool'],
#  ['brazil',
#   'cyberattack',
#   'hacker',
#   'space',
#   'polit',
#   'middle east',
#   'u.s.',
#   'world'],
#  ['box', 'busi', 'facebook', 'pinterest', 'women in tech'],
#  ['busi',
#   'live stream',
#   'media',
#   'nbc',
#   'nbc olymp',
#   'sport',
#   'winter olympics 2014'],
#  ['box offic',
#   'entertain',
#   'movi',
#   'jennifer lawr',
#   'the hunger gam',
#   'the hunger games: mockingjay - part 1'],
#  ['middle east', 'islamic st', 'mount sinjar', 'world', 'yazidi'],
#  ['apps and softwar',
#   'clean instal',
#   'how to',
#   'os x',
#   'maverick',
#   'os x maverick',
#   'tech'],
#  ['busi', 'linkedin', 'startup'],
#  ['australia', 'brisban', 'climat', 'flood', 'queensland', 'rain', 'world'],
#  ['archaeolog', 'artifact', 'uk', 'world'],
#  ['entertain', 'galleri', 'game', 'ios gam', 'temple run'],
#  ['space', 'snow', 'u.s.', 'world', 'climat'],
#  ['drake',
#   'emoji',
#   'entertain',
#   'instagram',
#   'music',
#   'photographi',
#   'tattoo',
#   'watercool'],
#  ['broadway', 'hollywood', 'mike nichol', 'movi', 'u.s.', 'world'],
#  ['ebola', 'new york c', 'nyc', 'u.s.', 'world'],
#  ['amazon',
#   'amazon prim',
#   'apps and softwar',
#   'fire o',
#   'fire phon',
#   'kindl',
#   'kindle fir',
#   'mobil',
#   'tech'],
#  ['entertain', 'ipad', 'surface tablet', 'nba', 'sport', 'steve ballm'],
#  ['chart of the day', 'mobil', 'smartphon', 'tech'],
#  ["conan o'brien",
#   'entertain',
#   'entertian',
#   'televis',
#   'video',
#   'video',
#   'watercool'],
#  ['commun',
#   'event',
#   'lgbt',
#   'pride parad',
#   'twitter',
#   'u.s.',
#   'u.s. & world',
#   'u.s.',
#   'world',
#   'work & play'],
#  ['ice', 'photographi', 'uk', 'watercool', 'climat', 'world'],
#  ['app',
#   'apps and softwar',
#   'parent',
#   'contributor',
#   'family & par',
#   'home',
#   'lifestyl',
#   'mobil',
#   'tech'],
#  ['busi', 'directv', 'media'],
#  ['banshe',
#   'cinemax',
#   'entertain',
#   'social media',
#   'social tv',
#   'televis',
#   'video',
#   'vine'],
#  ['appl', 'dev & design', 'gadget', 'patent', 'portabl', 'tech'],
#  ['family & par',
#   'high school',
#   'instagram',
#   'lifestyl',
#   'parent',
#   'photographi',
#   'social media',
#   'student'],
#  ['chip', 'gadget', 'game', 'haswel', 'intel', 'iri', 'laptop', 'tech'],
#  ['art', 'circu', 'engin', 'lifestyl', 'work & play'],
#  ['mashread', 'entertain', 'harry pott', 'photographi'],
#  ['middle east', 'islamic st', 'polit', 'shia', 'shiit', 'sunni', 'world'],
#  ['apps and softwar', 'chicago', 'data', 'u.s.', 'world'],
#  ['busi', 'stock', 'twitter'],
#  ['beyonc', 'celebr', 'entertain', 'music', 'spotifi'],
#  ['celebrity product',
#   'entertain',
#   'fake',
#   'product',
#   'scam',
#   'scammer',
#   'televis',
#   'twitter'],
#  ['car', 'tech', 'tesla motor', 'tesla model '],
#  ['grover',
#   'kid presid',
#   'social good',
#   'televis',
#   'video',
#   'video',
#   'viral video',
#   'watercool'],
#  ['burger k', 'first to know', 'singular', 'tech'],
#  ['gadget', 'tech', 'travel', 'travel & leisur'],
#  ['entertain', 'landon donovan', 'soccer', 'sport', 'u.s.', 'video', 'video'],
#  ['dev & design', 'gadget', 'googl', 'smart contact lens', 'tech'],
#  ['apps and softwar',
#   'aquatop',
#   'bathtub',
#   'dev & design',
#   'gadget',
#   'kinect',
#   'newsi',
#   'tech',
#   'touch',
#   'touchscreen',
#   'video',
#   'video'],
#  ['busi', 'live chat', 'startup', 'yec'],
#  ['goat', 'video', 'video', 'viral video', 'watercool', 'youtub'],
#  ['iphone 5',
#   'case',
#   'lifeproof',
#   'mashable choic',
#   'mobil',
#   'review',
#   'tech'],
#  ['dev & design', 'mobil', 'solar energi', 'solar pow', 'tech'],
#  ['automatt', 'busi', 'media', 'startup'],
#  ['cardboard', 'costum', 'diy', 'halloween', 'watercool'],
#  ['airlin', 'climat', 'hawaii', 'hurricane isel', 'julio', 'u.s.', 'world'],
#  ['android tv', 'chromecast', 'dev & design', 'googl', 'google tv', 'tech'],
#  ['apps and softwar', 'tech', 'video', 'youtub'],
#  ['turtl', 'video', 'video', 'viral video', 'watercool'],
#  ['climat', 'mudslid', 'u.s.', 'world'],
#  ['phone hack', 'world'],
#  ['entertain', 'nfl', 'sport'],
#  ['dad', 'famili', 'militari', 'video', 'video', 'watercool'],
#  ['appl', 'apps and softwar', 'desktop', 'gadget', 'imac', 'mobil', 'tech'],
#  ['beyonc', 'celebr', 'humor', 'sport', 'video', 'video', 'watercool'],
#  ['design',
#   'include in infographic carousel',
#   'infograph',
#   'pinterest',
#   'social media'],
#  ['inspir', 'video', 'video', 'viral video', 'watercool'],
#  ['cnn', 'u.s.', 'world', 'world trade cent', 'wtc'],
#  ['lolcat', 'social media', 'twitter'],
#  ['diy', 'photographi', 'video', 'video', 'viral video', 'watercool'],
#  ['convers',
#   'lifestyl',
#   'photographi',
#   'travel',
#   'travel & leisur',
#   'watercool'],
#  ['andy murray',
#   'entertain',
#   'maria sharapova',
#   'roger feder',
#   'serena william',
#   'sport',
#   'tenni',
#   'wimbledon'],
#  ['busi', 'facebook', 'market', 'sport', 'twitter'],
#  ['humor', 'video', 'video', 'viral video', 'watercool'],
#  ['college sport', 'sport', 'videobomb', 'video', 'video', 'watercool'],
#  ['funni', 'humor', 'quot', 'watercool'],
#  ['20th century fox',
#   'ape',
#   'dawn of the planet of the ap',
#   'entertain',
#   'movi',
#   'trailer',
#   'video'],
#  ['amazon',
#   'amazon instant video',
#   'amazon prim',
#   'entertain',
#   'online televis',
#   'televis',
#   'video'],
#  ['cable televis',
#   'entertain',
#   'hbo',
#   'true detect',
#   'true detective season 2',
#   'televis'],
#  ['anthony wein',
#   'campaign',
#   'investig',
#   'mayor',
#   'mobil',
#   'money',
#   'polit',
#   'sex & lov',
#   'text',
#   'u.s.',
#   'world'],
#  ['commemor', 'nelson mandela', 'south africa', 'u.s.', 'world'],
#  ['gadget',
#   'microsoft',
#   'surface tablet',
#   'mobil',
#   'nfl',
#   'sport',
#   'surface pro 2',
#   'surface pro 3',
#   'tech'],
#  ['bergdahl', 'middle east', 'taliban', 'united st'],
#  ['banned book', 'mashread', 'quot', 'watercool'],
#  ['polit', 'proposition 8', 'lgbt', 'u.s.', 'world'],
#  ['accessori',
#   'barnes and nobl',
#   'case',
#   'eread',
#   'gadget',
#   'galleri',
#   'home',
#   'lifestyl',
#   'mobil',
#   'tech',
#   'travel',
#   'travel & leisur',
#   'work & play'],
#  ['immigr', 'keystone xl', 'mark zuckerberg', 'polit', 'u.s.', 'world'],
#  ['justin bieb', 'rob ford', 'world'],
#  ['anim', 'photographi', 'watercool'],
#  ['entertain',
#   'follow',
#   'justin bieb',
#   'music',
#   'social media',
#   'twitter',
#   'video'],
#  ['california drought',
#   'climat',
#   'cold wint',
#   'polar vortex',
#   'snow',
#   'u.s.',
#   'world'],
#  ['busi', 'job', 'market'],
#  ['polit',
#   'crime',
#   'department of homeland secur',
#   'ricin',
#   'silk road',
#   'u.s.',
#   'world'],
#  ['apps and softwar',
#   'dev & design',
#   'mobil',
#   'newark airport',
#   'otg',
#   'tech',
#   'travel',
#   'travel & leisur',
#   'united airlin',
#   'u.s.'],
#  ['gopro', 'spiderman', 'video', 'video', 'viral video', 'watercool'],
#  ['busi', 'comedi', 'mad magazin', 'media'],
#  ['busi', 'gm', 'mary barra', 'polit', 'recal', 'u.s.'],
#  ['activ',
#   'amnesty intern',
#   'entertain',
#   'music',
#   'new york',
#   'pussy riot',
#   'world'],
#  ['entertain', 'movi', 'game'],
#  ['entertain', 'survivor', 'televison', 'televis'],
#  ['convers', 'justin bieb', 'twitter', 'watercool'],
#  ['apps and softwar',
#   'entertain',
#   'europ',
#   'game',
#   'playstation 4',
#   'psn',
#   'soni'],
#  ['health & fit', 'home', 'ipod', 'isleep', 'lifestyl', 'wireless'],
#  ['busi', 'media', 'midterm', 'polit', 'u.s.'],
#  ['bbc',
#   'comedi',
#   'entertain',
#   'hulu',
#   'review',
#   'steraming video',
#   'streaming tv',
#   'televis',
#   'video'],
#  ['ashley wagn',
#   'meme',
#   'olymp',
#   'photographi',
#   'sport',
#   'watercool',
#   'winter olympics 2014',
#   'world'],
#  ['entertain', 'music', 'music video', 'robin thick'],
#  ['arrested develop', 'entertain', 'televis', 'video', 'video'],
#  ['parent',
#   'baby product',
#   'dev & design',
#   'family & par',
#   'home technolog',
#   'lifestyl'],
#  ['parent', 'family & par', 'growth', 'health & fit', 'height', 'lifestyl'],
#  ['icann', 'michael bloomberg', 'new york c', 'tld', 'u.s.', 'world'],
#  ['appl', 'busi', 'stock'],
#  ['advertis',
#   'brand',
#   'busi',
#   'loglin',
#   'market',
#   'open forum',
#   'small busi',
#   'startup'],
#  ['travel',
#   'airplan',
#   'lifestyl',
#   'thanksgiving travel',
#   'travel & leisur',
#   'u.s.'],
#  ['apps and softwar',
#   'bluetooth',
#   'dev & design',
#   'gadget',
#   'mobil',
#   'review',
#   'tech'],
#  ['australia', 'australia prime minist', 'gough whitlam', 'polit', 'world'],
#  ['internet freedom', 'middle east', 'u.s.', 'world'],
#  ['apps and softwar', 'facebook', 'facebook hom', 'mobil', 'social media'],
#  ['advertis', 'busi', 'infograph', 'market', 'mobil', 'mobile advertis'],
#  ['social media', 'twitter', 'vine', 'vine app'],
#  ['busi', 'fashion', 'fashion app', 'pricegrabb', 'snapett', 'startup'],
#  ['california', 'environment', 'plastic', 'u.s.', 'world'],
#  ['apps and softwar',
#   'disabl',
#   'educ',
#   'lifestyl',
#   'sign languag',
#   'social good',
#   'social media',
#   'work & play'],
#  ['campaign',
#   'dev & design',
#   'dicycl',
#   'gadget',
#   'global innovation seri',
#   'green',
#   'segway',
#   'tech',
#   'travel',
#   'travel & leisur',
#   'video',
#   'video',
#   'work & play'],
#  ['art', 'convers', 'photographi', 'u.s.', 'watercool', 'weird', 'wtf'],
#  ['muppet', 'photographi', 'travel', 'travel & leisur', 'watercool'],
#  ['busi',
#   'e-commerc',
#   'of a kind',
#   'small busi',
#   'the origin',
#   'travel',
#   'travel & leisur'],
#  ['polit', 'twitter', 'u.s.', 'world', "valentine's day"],
#  ['apps and softwar', 'busi', 'mashable must read', 'lastpass', 'password'],
#  ['polit', 'bashar al-assad', 'john kerri', 'middle east', 'u.s.', 'world'],
#  ['bill gat', 'charlie sheen', 'convers', 'infograph', 'watercool'],
#  ['entertain', 'movi', 'mad max', 'video', 'video'],
#  ['apps and softwar',
#   'dev & design',
#   'research',
#   'tech',
#   'visual recognition technolog',
#   'work & play',
#   'zoolog'],
#  ['chinese new year', 'hors', 'photographi', 'watercool', 'world'],
#  ['entertain', 'music', 'st lucia', 'throwback tunesday'],
#  ['car', 'dev & design', 'gadget', 'tech'],
#  ['amazon dron',
#   'apps and softwar',
#   'dev & design',
#   'driverless car',
#   'drone',
#   'gadget',
#   'implant',
#   'mobil',
#   'ray kurzweil',
#   'robot',
#   'self-driving car',
#   'tech',
#   'the singular',
#   'u.s.',
#   'wearable tech'],
#  ['georgia',
#   'gulf',
#   'gulf of mexico',
#   'national weather servic',
#   'climat',
#   'u.s.',
#   'world'],
#  ['entertain', 'mobile entertain', 'sxsw', 'televis'],
#  ['gadget', 'raspberry pi', 'tech'],
#  ['appl', 'macbook pro', 'mobil', 'tech'],
#  ['christma',
#   'holiday',
#   'parodi',
#   'video',
#   'video',
#   'viral video',
#   'watercool',
#   'youtub'],
#  ['busi', 'job search seri', 'job', 'mashable car'],
#  ['fcc', 'net neutrality ', 'tech', 'u.s.'],
#  ['meme', 'photographi', 'sxsw', 'televis', 'watercool'],
#  ['apps and softwar', 'facebook', 'pandora', 'tech'],
#  ['cat',
#   'christma',
#   'funni',
#   'holiday',
#   'video',
#   'video',
#   'viral video',
#   'watercool'],
#  ['protests in ferguson', ' missouri ', 'u.s.', 'world'],
#  ['cyberwar', 'cyberweapon', 'malwar', 'u.s.', 'world'],
#  ['crowdfund',
#   'entertain',
#   'olymp',
#   'reddit',
#   'sport',
#   'winter olympics 2014'],
#  ['downton abbey', 'entertain', 'televis', 'uk', 'world'],
#  ['app', 'apps and softwar', 'ipad', 'iphon', 'mobil', 'tech'],
#  ['fire',
#   'home',
#   'home secur',
#   'home technolog',
#   'iphone dock',
#   'iphone dock',
#   'safeti',
#   'tech'],
#  ['advertis', 'busi', 'medical marijuana'],
#  ['competit', 'spain', 'world'],
#  ['casey kasem', 'death', 'entertain', 'music', 'radio'],
#  ['charger', 'gadget', 'mobil', 'myth', 'smartphon', 'tech', 'video', 'video'],
#  ['apps and softwar',
#   'biz ston',
#   'creativ',
#   'how to',
#   'jelli',
#   'social media'],
#  ['ebola', 'world'],
#  ['diy', 'holiday', 'home', 'lifestyl', 'watercool', 'wrapping pap'],
#  ['art', 'art basel', 'festiv', 'music', 'photographi', 'u.s.', 'world'],
#  ['art',
#   'convers',
#   'email',
#   'lifestyl',
#   'video',
#   'video',
#   'vimeo',
#   'watercool',
#   'work & play'],
#  ['new delhi', 'tiger', 'world'],
#  ['homeless', 'video', 'video', 'viral video', 'watercool'],
#  ['entertain', 'fifa', 'goal', 'soccer', 'sport', 'world cup'],
#  ['david lynch', 'meme', 'nostalgia', 'televis', 'twin peak', 'watercool'],
#  ['evolut', 'gadget', 'mice', 'robot', 'scientist', 'world'],
#  ['craigslist', 'missed connect', 'romanc', 'watercool'],
#  ['electron', 'gadget', 'microsoft', 'mobil', 'nokia', 'smartphon', 'tech'],
#  ['brazil',
#   'clint dempsey',
#   'uk',
#   'entertain',
#   'itali',
#   'photographi',
#   'soccer',
#   'sport',
#   'usmnt',
#   'world cup'],
#  ['bane',
#   'batman',
#   'cat',
#   'comic',
#   'fov',
#   'game',
#   'parodi',
#   'video',
#   'video',
#   'watercool'],
#  ['entertain', 'game', 'grand theft auto v', 'rockstar gam'],
#  ['entertain',
#   'infograph',
#   'social tv',
#   'social tv chart',
#   'trendrr',
#   'televis'],
#  ['beyonc',
#   'convers',
#   'hashtag',
#   'humor',
#   'music',
#   'social media',
#   'twitter',
#   'watercool'],
#  ['sport', 'video', 'video', 'watercool'],
#  ['internet mem', 'meme', 'photobomb', 'photographi', 'reddit', 'watercool'],
#  ['colleg', 'comic', 'graduat', 'humor', 'toothpaste for dinn', 'watercool'],
#  ['advertis',
#   'busi',
#   'gmail',
#   'googl',
#   'market',
#   'microsoft',
#   'microsoft outlook'],
#  ['busi',
#   'business product',
#   'collabor',
#   'health & fit',
#   'health & fit',
#   'job',
#   'standing desk',
#   'work & play'],
#  ['dev & design',
#   'donhou bicycl',
#   'invent',
#   'newsi',
#   'tech',
#   'travel',
#   'travel & leisur',
#   'work & play'],
#  ['busi', 'gadget', 'invest', 'justin timberlak'],
#  ['gadget',
#   'googl',
#   'google glass',
#   'google glass',
#   'mobil',
#   "mother's day 2014",
#   'tech',
#   'video',
#   'video'],
#  ['soccer', 'sport', 'world', 'world cup'],
#  ['contract disput',
#   'directv',
#   'entertain',
#   'the weather channel',
#   'televis',
#   'u.s.',
#   'climat'],
#  ['busi', 'media', 'newspap', 'the guardian'],
#  ['celebr', 'photographi', 'shruggi', 'watercool'],
#  ['busi', 'facebook ipo', 'nasdaq'],
#  ['lifestyl', 'scam', 'tourism', 'travel', 'travel & leisur'],
#  ['bacteria', 'diseas', 'dna', 'scientist', 'u.s.', 'world'],
#  ['3d', 'entertain', 'game', 'headset', 'virtual r'],
#  ['busi', 'retail', 'shutl', 'startup', 'the launchpad'],
#  ['2013 webby award', 'social media', 'webby award'],
#  ['facebook',
#   'googl',
#   'graph search',
#   'microsoft b',
#   'social media',
#   'social network'],
#  ['campaign',
#   'election 2016',
#   'mayor',
#   'photographi',
#   'polit',
#   'rob ford',
#   'toronto',
#   'world'],
#  ['vegetarian', 'video', 'video', 'viral video', 'watercool'],
#  ['darpa', 'dev & design', 'u.s.', 'us armi', 'world'],
#  ['3g', '4g', 'china', 'mobil', 'smartphone subscrib', 'tech', 'world'],
#  ['dallas-fort worth', 'ebola', 'u.s.', 'world'],
#  ['disney', 'entertain', 'movi', 'photographi', 'watercool'],
#  ['busi',
#   'customer relationship manag',
#   'customer servic',
#   'market',
#   'small busi',
#   'startup'],
#  ['appl', 'batteri', 'iphone 5', 'mobil', 'tech'],
#  ['jimmy kimmel', 'televis', 'video', 'video', 'watercool'],
#  ['space', 'star', 'univers', 'u.s.', 'world'],
#  ['new york c', 'subway', 'u.s.', 'world'],
#  ['gadget',
#   'galaxy not',
#   'galaxy note 3',
#   'ifa',
#   'mobil',
#   'samsung',
#   'samsung galaxy not',
#   'tech'],
#  ['busi',
#   'home',
#   'job list',
#   'job',
#   'market',
#   'work from hom',
#   'work & play',
#   'working from hom'],
#  ['apps and softwar',
#   'basecamp',
#   'busi',
#   'contributor',
#   'dev & design',
#   'freelanc',
#   'incom',
#   'job',
#   'startup',
#   'web design',
#   'work & play'],
#  ['busi', 'fcc', 'media', 'net neutrality '],
#  ['polit', 'nelson mandela', 'raul castro', 'u.s.', 'world'],
#  ['busi', 'food', 'startup', 'the launchpad', 'work & play'],
#  ['anchorman', 'mashread', 'entertain', 'movi', 'paramount', 'ron burgundi'],
#  ['mashread',
#   'movi',
#   'the fault in our star',
#   'travel',
#   'travel & leisur',
#   'watercool',
#   'work & play',
#   'young adult'],
#  ['gp', 'u.s.', 'world'],
#  ['galaxy s5',
#   'korea',
#   'mobil',
#   'samsung',
#   'samsung galaxy s5',
#   'sk telecom',
#   'tech',
#   'world'],
#  ['busi', 'facebook', 'googl', 'sheryl sandberg'],
#  ['entertain', 'footbal', 'sport', 'super bowl'],
#  ['art', 'law', 'photographi', 'watercool'],
#  ['protests in ferguson', ' missouri ', 'st. loui', 'u.s.', 'world'],
#  ['harlem shak', 'music', 'video', 'video', 'viral video', 'watercool'],
#  ['apps and softwar',
#   'australia',
#   'foxtel',
#   'game of card',
#   'mashable must read',
#   'netflix',
#   'quickflix',
#   'televis',
#   'world'],
#  ['advertis', 'busi', 'media', 'tumblr'],
#  ['entertain', 'movi', 'jessica alba'],
#  ['contributor',
#   'entertain',
#   'gadget',
#   'game',
#   'guinness world record',
#   'world record'],
#  ['cute kid', 'meme', 'video', 'video', 'viral video', 'watercool'],
#  ['car',
#   'dev & design',
#   'electr',
#   'home',
#   'home',
#   'power',
#   'thorium',
#   'world'],
#  ['app',
#   'bluetooth',
#   'dev & design',
#   'gadget',
#   'gestur',
#   'tech',
#   'wearable tech'],
#  ['2014', 'photographi', 'watercool', 'worst', 'year-end'],
#  ['advertis', 'amazon', 'busi', 'fire phon', 'market', 'mobil'],
#  ['apps and softwar', 'microsoft', 'tech', 'windows 8.1', 'windows xp'],
#  ['busi', 'job interview', 'job search seri', 'job', 'mashable car'],
#  ['comic', 'entertain', 'movi', 'godzilla', 'humor'],
#  ['apps and softwar', 'dev & design', 'microsoft', 'start menu'],
#  ['comedi', 'movi', 'social media', 'twitter', 'u.s.', 'world', 'vine'],
#  ['2014 oscar',
#   'celebr',
#   'movi',
#   'matthew mcconaughey',
#   'the oscar',
#   'photographi',
#   'watercool'],
#  ['collegehumor', 'funni', 'video', 'video', 'viral video', 'watercool'],
#  ['galaxy s4', 'iphone 5', 'mobil', 'samsung', 'tech'],
#  ['brooklyn', 'connected home show & tel', 'home', 'lifestyl', 'lumoback'],
#  ['entertain',
#   'madonna',
#   'music',
#   'music',
#   'social tv',
#   'sport',
#   'televis',
#   'world cup'],
#  ['crime',
#   'footbal',
#   'mashable must read',
#   'market',
#   'national football leagu',
#   'nfl',
#   'sport',
#   'u.s.',
#   'world',
#   'women'],
#  ['entertain', 'jimmy kimmel', 'laker', 'nba', 'sport', 'video', 'video'],
#  ['entertain', 'mlb', 'sport'],
#  ['advertis', 'social good', 'video', 'video', 'viral video', 'watercool'],
#  ['gadget',
#   'microsoft',
#   'surface tablet',
#   'mobil',
#   'surface 2',
#   'tech',
#   'windows 8.1',
#   'windows rt'],
#  ['antar', 'space', 'orbital technolog', 'u.s.', 'world'],
#  ['comedi',
#   'movi',
#   'sketch comedi',
#   'video',
#   'video',
#   'viral video',
#   'watercool'],
#  ['appl', 'apple watch ', 'gadget', 'tech', 'work & play'],
#  ['entertain', 'music'],
#  ['cdc',
#   'government shutdown',
#   'health & fit',
#   'health & fit',
#   'polit',
#   'shutdown',
#   'u.s.',
#   'world'],
#  ['gadget', 'lifestyl', 'sexism', 'tablet', 'womens right'],
#  ['entertain', 'nfl', 'sport'],
#  ['entertain', 'music', 'sxsw', 'u.s.'],
#  ['apps and softwar', 'dev & design', 'email', 'futur', 'gmail', 'tech'],
#  ['health & fit',
#   'pinterest',
#   'punchfork',
#   'recipe pin',
#   'search',
#   'social media'],
#  ['family & par', 'health & fit', 'health & fit', 'lifestyl', 'maker fair'],
#  ['art', 'george w. bush', 'photographi', 'u.s.', 'watercool', 'world'],
#  ['busi', 'digital media', 'media', 'the new york tim'],
#  ['entertain',
#   'movi',
#   'lego',
#   'video',
#   'video',
#   'viral video',
#   'watercool',
#   'youtub'],
#  ['akamai', 'appl', 'busi', 'first to know', 'mobil', 'twitter'],
#  ['celebr', 'entertain', 'movi', 'hollywood', 'tony award', 'televis'],
#  ['farm', 'space', 'mars miss', 'world'],
#  ['appl', 'gadget', 'mac', 'steve job', 'tech'],
#  ['busi', 'mobil', 'mobli', 'pheed', 'startup'],
#  ['animated gif', 'meme', 'mtv', 'televis', 'watercool'],
#  ['apollo 11', 'polit', 'space', 'u.s.', 'world'],
#  ['android',
#   'appl',
#   'edit-samsung-galaxy-siv',
#   'galaxy s iv',
#   'iphone 5',
#   'mobil',
#   'samsung',
#   'tech'],
#  ['apps and softwar',
#   'entertain',
#   'game',
#   'samsung gear vr',
#   'temple run',
#   'virtual r'],
#  ['earthquak', 'gadget', 'napa', 'tech'],
#  ['entertain', 'fiona appl', 'music', 'the affair', 'televis'],
#  ['entertain', 'movi', 'james franco', 'media', 'sony hack', 'the interview'],
#  ['busi', 'chart of the day', 'googl', 'lobbi', 'polit', 'tech', 'u.s.'],
#  ['game', 'guitar', 'music', 'video', 'video', 'watercool', 'youtub'],
#  ['fbi', 'hack', 'privaci', 'surveil', 'u.s.', 'world'],
#  ['malaysia airlin',
#   'malaysia airlines flight 17 in ukrain',
#   'ukraine ',
#   'world'],
#  ['music',
#   'pop mus',
#   'video',
#   'video',
#   'viral video',
#   'watercool',
#   'youtub',
#   'youtub'],
#  ['histori',
#   'life magazin',
#   'photographi',
#   'united kingdom',
#   'u.s.',
#   'world',
#   'world war 2'],
#  ['apps and softwar',
#   'microsoft',
#   'microsoft outlook',
#   'outlook.com',
#   'tech',
#   'webmail'],
#  ['movi',
#   'geek',
#   'humor',
#   'the lord of the r',
#   'tl;dw',
#   'video',
#   'video',
#   'watercool'],
#  ['2020',
#   'olymp',
#   'promot',
#   'world',
#   'video',
#   'video',
#   'viral video',
#   'watercool'],
#  ['google doodl', 'maria calla', 'u.s.', 'world'],
#  ['middle east', 'israel and gaza', 'world'],
#  ['facebook',
#   'how to',
#   'imag',
#   'market',
#   'media',
#   'pinterest',
#   'social media',
#   'twitter',
#   'work & play'],
#  ['cathol', 'easter', 'holy b', 'jesu', 'religion', 'spiritu', 'world'],
#  ['4k video', 'gadget', 'video', 'video', 'watercool', 'youtub'],
#  ['entertain',
#   'hackers and hook',
#   'hbo',
#   'mike judg',
#   'peter thiel',
#   'pied pip',
#   'silicon valley',
#   'startup',
#   'televis'],
#  ['busi',
#   'disney',
#   'movi',
#   'stock quot',
#   'stock',
#   'televis',
#   'walt disney compani',
#   'work & play'],
#  ['advertis', 'busi', 'esur', 'market', 'twitter'],
#  ['facebook', 'hacker', 'middle east', 'twitter', 'u.s.', 'world'],
#  ['at&t;',
#   'blackberri',
#   'blackberry 10',
#   'blackberry q10',
#   'blackberry z10',
#   'mobil',
#   'sprint',
#   't-mobil',
#   'tech',
#   'verizon'],
#  ['gadget', 'mirrorless camera', 'mobil', 'nx3000', 'samsung', 'tech'],
#  ['design', 'dev & design', 'social media', 'tumblr'],
#  ['comput', 'data', 'dev & design', 'inform', 'tech', 'teleport'],
#  ['busi', 'contributor', 'crowdfund', 'kickstart', 'startup'],
#  ['art', 'logo', 'photographi', 'starbuck', 'watercool'],
#  ['apl', 'gadget', 'healthkit', 'apple watch ', 'smartwatch', 'tech'],
#  ['activist',
#   'facebook',
#   'gun right',
#   'nra',
#   'open carry texa',
#   'polit',
#   'target',
#   'twitter',
#   'u.s.',
#   'world'],
#  ['airbnb',
#   'hotel',
#   'lifestyl',
#   'sharing economi',
#   'travel',
#   'travel & leisur',
#   'u.s.'],
#  ['accessori',
#   'gadget',
#   'apple watch ',
#   'kickstart',
#   'mobil',
#   'tech',
#   'wearable tech',
#   'wearable technolog'],
#  ['human traffick', 'mobil', 'social good', 'text', 'u.s.', 'world'],
#  ['mobil', 'mobile world congress', 'opera', 'opera max', 'tech'],
#  ['apps and softwar',
#   'camera',
#   'cloud',
#   'cloud storag',
#   'dev & design',
#   'gadget',
#   'kickstart',
#   'kickstarter campaign',
#   'memori',
#   'storag',
#   'tech',
#   'video',
#   'wi-fi'],
#  ['mashread',
#   'facebook',
#   'facebook timelin',
#   'facebook timelin',
#   'social media'],
#  ['skateboard',
#   'sport',
#   'tony hawk',
#   'video',
#   'video',
#   'viral video',
#   'watercool'],
#  ['community manag', 'social media', 'twitter', 'twitter chat'],
#  ['beer', 'craft', 'diy', 'watercool'],
#  ['ariana grand',
#   'cristiano ronaldo',
#   'drake',
#   'dropbox',
#   'frank ocean',
#   'justin bieb',
#   'liam payn',
#   'louis tomlinson',
#   'one direct',
#   'retweet',
#   'social media',
#   'twitter',
#   'u.s.',
#   'world'],
#  ['gadget', 'robot', 'world', 'world war 2'],
#  ['advertis', 'busi', 'googl', 'mobile advertis'],
#  ['gadget',
#   'mobil',
#   'review',
#   'samsung',
#   'samsung shap',
#   'tech',
#   'wi-fi speak',
#   'wireless speak'],
#  ['entertain', 'movi', 'j.j. abram', 'star wars episode vii'],
#  ['polit', 'code.org', 'code', 'educ', 'eric cantor', 'u.s.', 'world'],
#  ['debt ceil',
#   'govern',
#   'government shutdown',
#   'polit',
#   'u.s.',
#   'us govern',
#   'world'],
#  ['ama', 'bill gat', 'microsoft', 'reddit', 'tech'],
#  ['anim',
#   'app',
#   'apps and softwar',
#   'ask a dev',
#   'dev & design',
#   'develop',
#   'mobil',
#   'server-sent ev',
#   'tech',
#   'web app',
#   'websocket'],
#  ['space', 'chris hadfield', 'video', 'video', 'watercool'],
#  ['polit', 'eric shinseki', 'u.s.', 'world', 'veterans affair'],
#  ['2013',
#   'advertis',
#   'brand',
#   'disney',
#   'facebook',
#   'instagram',
#   'market',
#   'mtv',
#   'national geograph',
#   'nike',
#   'samsung',
#   'social media',
#   'youtub'],
#  ['googl', 'google new', 'google tax', 'spain', 'world'],
#  ['apertur',
#   'appl',
#   'apps and softwar',
#   'dev & design',
#   'iphoto',
#   'os x yosemit',
#   'tech',
#   'yosemit'],
#  ['dad',
#   'family & par',
#   'parent',
#   'home',
#   'photographi',
#   'pinterest',
#   'watercool',
#   'work & play'],
#  ['jimmy kimmel', 'televis', 'video', 'video', 'watercool'],
#  ['3d printed car',
#   '3d print',
#   'dev & design',
#   'gadget',
#   'local motor',
#   'tech'],
#  ['bus travel',
#   'greyhound',
#   'lifestyl',
#   'megabu',
#   'transport',
#   'travel',
#   'travel & leisur',
#   'u.s.',
#   'wanderu'],
#  ['gadget',
#   'galaxy gear',
#   'galaxy note 10.1 2014',
#   'galaxy note 3',
#   'mobil',
#   'samsung',
#   'tech'],
#  ['apps and softwar',
#   'facebook',
#   'facebook messeng',
#   'hack',
#   'mobil',
#   'mobile pay',
#   'softwar',
#   'tech'],
#  ['bacteria',
#   'diseas',
#   'health & fit',
#   'medical sci',
#   'research',
#   'u.s.',
#   'world'],
#  ['apps and softwar',
#   'domain registrar',
#   'generic top level domain',
#   'gtld',
#   'icann',
#   'tech'],
#  ['lawrence lessig', 'polit', 'social media', 'tumblr', 'u.s.', 'world'],
#  ['celebr',
#   "conan o'brien",
#   'entertain',
#   'the flaming lip',
#   'miley cyru',
#   'music',
#   'the beatl',
#   'televis'],
#  ['2014 oscar',
#   '86th academy award',
#   'entertain',
#   'movi',
#   'the oscar',
#   'televis',
#   'twitter'],
#  ['appl', 'asu', 'gadget', 'tech'],
#  ['entertain', 'mlb', 'sport'],
#  ['entertain',
#   'funny or di',
#   'parodi',
#   'taylor swift',
#   'video',
#   'video',
#   'viral video',
#   'watercool'],
#  ['busi', 'game', 'mobile gam', 'zynga'],
#  ['gadget',
#   'googl',
#   'google glass',
#   'google glass',
#   'tech',
#   'travel',
#   'travel & leisur'],
#  ['parent', 'brand', 'family & par', 'lifestyl', 'name'],
#  ['ukraine ', 'world'],
#  ['the new york tim', 'tesla motor'],
#  ['american music award',
#   'entertain',
#   'music',
#   'taylor swift',
#   'televis',
#   'video',
#   'video',
#   'watercool'],
#  ['bitcoin', 'busi', 'facebook', 'first to know', 'googl', 'mobil'],
#  ['jet lag',
#   'lifestyl',
#   'light',
#   'time zon',
#   'travel',
#   'travel & leisur',
#   'wearable devic',
#   'wearable tech'],
#  ['appl', 'busi', 'stock'],
#  ['busi', 'googl', 'google for entrepreneur', 'startup', 'tech hub', 'world'],
#  ['basebal',
#   'climat',
#   'epa',
#   'ernest moniz',
#   'fenway park',
#   'gina mccarthi',
#   'polit',
#   'u.s.',
#   'world'],
#  ['dev & design',
#   'gadget',
#   'google glass',
#   'google glass',
#   'newsi',
#   'sourcebit',
#   'tech',
#   'work & play'],
#  ['apps and softwar', 'microsoft', 'mobil', 'satya nadella', 'tech'],
#  ['jimmy kimmel',
#   'jimmy kimmel l',
#   'taylor swift',
#   'televis',
#   'video',
#   'video',
#   'viral video',
#   'watercool'],
#  ['busi', 'job', 'freelanc', 'media', 'small busi', 'startup', 'twitter'],
#  ['busi', 'chart', 'facebook'],
#  ['app',
#   'apps and softwar',
#   'articl',
#   'audio',
#   'mercedes-benz',
#   'tech',
#   'travel',
#   'travel & leisur',
#   'work & play'],
#  ['blogger', 'internet freedom', 'law', 'polit', 'world'],
#  ['movi',
#   'food',
#   'photographi',
#   'pizza',
#   'teenage mutant ninja turl',
#   'tmnt',
#   'televis',
#   'ugc',
#   'watercool'],
#  ['appl',
#   'apple watch ',
#   'apps and softwar',
#   'fashion',
#   'gadget',
#   'job',
#   'luxuri',
#   'mobil',
#   'tech',
#   'wearable tech'],
#  ['apps and softwar',
#   'ask a dev',
#   'design',
#   'dev & design',
#   'develop',
#   'develop',
#   'mobil',
#   'mobile develop',
#   'tech'],
#  ['comedian',
#   'jimmy fallon',
#   'the tonight show with jimmy fallon',
#   'televis',
#   'video',
#   'video',
#   'viral video',
#   'watercool'],
#  ["assassin's cre", 'entertain', 'review', 'game', 'ubisoft'],
#  ['70th golden glob',
#   'adel',
#   'entertain',
#   'golden glob',
#   'life of pi',
#   'music'],
#  ['breaking bad', 'celebr', 'entertain', 'televis', 'twitter'],
#  ['busi', 'microsoft', 'stock'],
#  ['privaci', 'right to know', 'u.s.', 'world'],
#  ['hotel', 'lifestyl', 'review', 'travel', 'travel & leisur', 'yelp'],
#  ['appl', 'polit', 'facebook', 'googl', 'u.s.', 'world', 'yahoo'],
#  ['advertis', 'busi', 'subaru', 'video', 'video', 'viral video', 'watercool'],
#  ['mashread',
#   'cute kid',
#   'read',
#   'video',
#   'video',
#   'viral video',
#   'watercool'],
#  ['apps and softwar', 'entertain', 'game', 'microsoft', 'used gam', 'xbox on'],
#  ['climat', 'kansa', 'oklahoma', 'record heat', 'u.s.', 'world', 'wildfir'],
#  ['disney',
#   'entertain',
#   'family & par',
#   'movi',
#   'game',
#   'ipad',
#   'lifestyl',
#   'second screen',
#   'tech'],
#  ['apps and softwar',
#   'feel happi',
#   'hungov',
#   'new years ev',
#   'social media',
#   'twitter',
#   'twitter data'],
#  ['brooklyn',
#   'entertain',
#   'food',
#   'music',
#   'new york c',
#   'video',
#   'video',
#   'vimeo'],
#  ['dad', 'family & par', 'humor', 'photographi', 'reddit', 'watercool'],
#  ['busi', 'job board', 'job', 'mashable job board'],
#  ['disney', 'entertain', 'movi', 'market', 'monsters univers', 'pixar'],
#  ['busi', 'directv', 'market', 'the weather channel', 'televis'],
#  ['advertis', 'analyt', 'brandspeak', 'busi', 'market', 'super bowl'],
#  ['malaysia airlin',
#   'malaysia airlines flight 370',
#   'malaysia',
#   'ocean',
#   'ocean debri',
#   'ocean trash',
#   'pacific garbage patch',
#   'trash gyr',
#   'u.s.',
#   'world'],
#  ['busi', 'design', 'twitter'],
#  ['china', 'moon', 'polit', 'space', 'u.s.', 'u.s.', 'world'],
#  ['entertain',
#   'music',
#   'reality tv',
#   'the-voic',
#   'televis',
#   'tv recap',
#   'video',
#   'video'],
#  ['parent',
#   'cyberbulli',
#   'family & par',
#   'home',
#   'internet',
#   'internet safeti',
#   'lifestyl',
#   'safeti'],
#  ['james foley', 'u.s.', 'world'],
#  ['world'],
#  ['bee', 'rfid', 'rfid chip', 'tech', 'world'],
#  ['greenpeac', 'japan', 'world', 'whale', 'whale', 'wildlif'],
#  ['apps and softwar', 'facebook', 'mobil', 'tech', 'twitter', 'vine'],
#  ['media', 'u.s.', 'world'],
#  ['busi',
#   'mashable must read',
#   'media',
#   'net neutrality ',
#   'netflix',
#   'televis',
#   'verizon',
#   'verizon fio'],
#  ['arrest', 'dustin diamond', 'entertain', 'saved by the bel', 'televis'],
#  ['polit', 'nelson mandela', 'photographi', 'u.s.', 'world', 'watercool'],
#  ['amazon',
#   'amazon fire phon',
#   'fire phon',
#   'mobil',
#   'photo servic',
#   'photo storag',
#   'tech'],
#  ['car', 'dev & design', 'ford', 'mustang', 'tech'],
#  ['health & fit',
#   'health & fit',
#   'lifestyl',
#   'research',
#   'safeti',
#   'u.s.',
#   'world'],
#  ['ben lash', 'market', 'meme', 'that was m', 'video', 'video', 'watercool'],
#  ['busi', "harper'", 'magazin', 'media'],
#  ['boston', 'boston marathon', 'u.s.', 'world'],
#  ['polit', 'ukraine ', 'world'],
#  ['american',
#   'busi',
#   'job',
#   'lifestyl',
#   'travel',
#   'travel & leisur',
#   'u.s.',
#   'work & play'],
#  ['entertain', 'protests in ferguson', ' missouri ', 'mlb', 'sport', 'u.s.'],
#  ['malaria', 'social good', 'social good summit', 'world', 'venmo'],
#  ['california', 'california drought', 'climat', 'u.s.', 'world'],
#  ['digital media', 'entertain', 'hbo', 'journal', 'media', 'televis'],
#  ['appl', 'app', 'apps and softwar', 'tech', 'video', 'video', 'wwdc 2014'],
#  ['entertain',
#   'game',
#   'microsoft',
#   'stream',
#   'xbox entertainment studio',
#   'xbox on'],
#  ['fifa',
#   'meme',
#   'miguel herrera',
#   'soccer',
#   'sport',
#   'watercool',
#   'world cup'],
#  ['astronomi',
#   'galaxy tab',
#   'imag',
#   'photographi',
#   'space',
#   'tech',
#   'u.s.',
#   'world'],
#  ['al-qaedo', 'hostag', 'u.s.', 'world', 'yemen'],
#  ['travel', 'national secur', 'travel & leisur', 'tsa', 'u.s.', 'world'],
#  ['advertis', 'busi', 'market', 'viral video'],
#  ["america's next top model",
#   'entertain',
#   'photographi',
#   'televis',
#   'tyra bank',
#   'video',
#   'video',
#   'watercool'],
#  ['appl', 'music monday', 'tech', 'tim cook', 'wwdc', 'wwdc 2013'],
#  ['disconnect',
#   'douglas rushkoff',
#   'instagram',
#   'lifestyl',
#   'mashread',
#   'photographi',
#   'present shock',
#   'travel',
#   'travel & leisur',
#   'unplug',
#   'work & play'],
#  ['arkansa', 'climat', 'mashable must read', 'tornado', 'u.s.', 'world'],
#  ['gun', 'ottawa', 'parliament hil', 'polit', 'shoot', 'u.s.', 'world'],
#  ['video', 'video', 'viral video', 'watercool', 'year end 2014', 'youtub'],
#  ['entertain', 'nfl', 'photographi', 'sport', 'watercool'],
#  ['appl', 'busi', 'gadget', 'iphon', 'iphone 5c'],
#  ['sesame street',
#   'televis',
#   'video',
#   'video',
#   'viral video',
#   'watercool',
#   'zachary levi'],
#  ['apps and softwar',
#   'ifa 2014',
#   'ifa2014',
#   'mobil',
#   'smartwatch',
#   'soni',
#   'tech'],
#  ['gadget',
#   'home',
#   'home secur',
#   'homes safeti',
#   'lifestyl',
#   'safer smart hom',
#   'travel',
#   'travel & leisur'],
#  ['cat', 'video', 'video', 'viral video', 'watercool'],
#  ['android',
#   'apps and softwar',
#   'google doc',
#   'google sheet',
#   'google slid',
#   'tech'],
#  ['gadget', 'robot', 'tech', 'video'],
#  ['biz ston',
#   'edgar allen po',
#   'entertain',
#   'movi',
#   'ron howard',
#   'travel',
#   'travel & leisur',
#   'twitter'],
#  ['citizen journ',
#   'facebook',
#   'hoax',
#   'how to',
#   'media',
#   'social media',
#   'spam'],
#  ['apps and softwar',
#   'dev & design',
#   'gadget',
#   'googl',
#   'google glass',
#   'google glass',
#   'mobil',
#   'moto 360',
#   'motorola',
#   'smart watch',
#   'tech',
#   'work & play'],
#  ['dev & design',
#   'futur',
#   'innov',
#   'social media',
#   'tech',
#   'travel',
#   'travel & leisur',
#   'twitter'],
#  ['apps and softwar',
#   'google glass',
#   'google glass',
#   'mobil',
#   'small busi',
#   'startup',
#   'tech',
#   'wearable tech'],
#  ['advertis', 'busi', 'facebook', 'market'],
#  ['gadget',
#   'gps tracker',
#   'home',
#   'lifestyl',
#   'lost and found',
#   'lost dev',
#   'lost phon',
#   'tracker'],
#  ['app',
#   'family & par',
#   'photographi',
#   'secret',
#   'secret',
#   'ugc',
#   'watercool'],
#  ['conflict',
#   'polit',
#   'election 2016',
#   'united st',
#   'u.s.',
#   'us govern',
#   'world',
#   'war'],
#  ['david bowi', 'funni', 'humor', 'music', 'watercool'],
#  ['armi',
#   'game',
#   'halo',
#   'u.s. militari',
#   'united st',
#   'u.s.',
#   'us armi',
#   'world'],
#  ['cuba', 'cuban twitt', 'u.s.', 'world', 'zunzuneo'],
#  ['contest', 'social media'],
#  ['apps and softwar',
#   'entertain',
#   'gadget',
#   'google glass',
#   'google glass',
#   'mobile porn',
#   'sex & lov'],
#  ['encrypt', 'mobil', 'privaci', 'surveil', 'u.s.', 'world'],
#  ['daytona 500', 'entertain', 'sport', 'u.s.', 'climat'],
#  ['national security council',
#   'polit',
#   'social media',
#   'twitter',
#   'u.s.',
#   'world'],
#  ['world cup',
#   'brazil',
#   'colombia',
#   'entertain',
#   'franc',
#   'germani',
#   'soccer',
#   'sport'],
#  ['middle east', 'islamic st', 'terror', 'world'],
#  ['basebal', 'korea', 'robot', 'tech', 'world'],
#  ['mashread',
#   'james mcbrid',
#   'lifestyl',
#   'the good lord bird',
#   'travel',
#   'travel & leisur',
#   'work & play'],
#  ['busi',
#   'job',
#   'marissa may',
#   'mashable infograph',
#   'richard branson',
#   'sheryl sandberg',
#   'work & play'],
#  ['gadget',
#   'holiday',
#   'labor day',
#   'tech',
#   'travel',
#   'travel & leisur',
#   'u.s.',
#   'work & play'],
#  ['bitcoin',
#   'busi',
#   'gold',
#   'rippl',
#   'startup',
#   'u.s.',
#   'virtual curr',
#   'world'],
#  ['breaking bad',
#   'convers',
#   'entertain',
#   'televis',
#   'video',
#   'video',
#   'watercool'],
#  ['entertain', 'gadget', 'game', 'how to', 'playstation 4', 'soni'],
#  ['govern',
#   'healthcar',
#   'obamacar',
#   'polit',
#   'uncle sam',
#   'u.s.',
#   'world',
#   'youtub'],
#  ['entertain', 'tv recap', 'televis', 'the walking dead', 'walking dead'],
#  ['amazon',
#   'barnes & nobl',
#   'mashread',
#   'busi',
#   'e-book',
#   'hachett',
#   'media',
#   'publish'],
#  ['apps and softwar',
#   'blackberri',
#   'busi',
#   'mobil',
#   'private market',
#   'stock'],
#  ['entertain', 'music', 'playlist', 'throwback tunesday'],
#  ['gadget', 'gift guid', 'holiday 2014', 'holiday', 'tech', 'tech gift'],
#  ['famili',
#   'family & par',
#   'home',
#   'lifestyl',
#   'onlin',
#   'social media',
#   'social network',
#   'work & play'],
#  ['acquisit',
#   'appl',
#   'bluetooth',
#   'busi',
#   'gadget',
#   'apple watch ',
#   'mobil',
#   'wearable tech'],
#  ['appl', 'apps and softwar', 'ibm', 'mobilefirst', 'small busi', 'tech'],
#  ['entertain', 'game', 'microsoft', 'new xbox', 'xbox 360'],
#  ['space', 'supernov', 'world'],
#  ['appl', 'busi', 'fortune 500'],
#  ['game', 'humor', 'pokemon', 'video', 'video', 'watercool'],
#  ['googl', 'icann', 'world', 'vint cerf'],
#  ['bro', 'high fiv', 'sport', 'video', 'video', 'viral video', 'watercool'],
#  ['ama',
#   'american music award',
#   'entertain',
#   'facebook',
#   'kesha',
#   'music',
#   'music video',
#   'pitbul',
#   'video'],
#  ['space', 'polit', 'twitter', 'u.s.', 'us govern', 'world'],
#  ['middle east', 'nuclear', 'u.s.', 'world'],
#  ['polit',
#   'democrat',
#   'executive act',
#   'immigr',
#   'republican',
#   'u.s.',
#   'world'],
#  ['lifestyl',
#   'uk',
#   'photographi',
#   'toy',
#   'travel',
#   'travel & leisur',
#   'watercool',
#   'weird new'],
#  ['busi',
#   'freelanc',
#   'job',
#   'small busi',
#   'startup',
#   'travel',
#   'travel & leisur',
#   'work & play'],
#  ['lego',
#   'short film',
#   'video',
#   'video',
#   'viral video',
#   'watercool',
#   'work & play'],
#  ['disney', 'e3', 'e3 2013', 'entertain', 'fantast', 'game'],
#  ['busi',
#   'health & fit',
#   'mashable must read',
#   'law',
#   'polit',
#   'u.s.',
#   'world',
#   'women'],
#  ['googl', 'u.s.', 'world'],
#  ['advertis',
#   'busi',
#   'car',
#   'kia',
#   'super bowl',
#   'superbowl ad',
#   'the matrix',
#   'video',
#   'video',
#   'viral video'],
#  ['apps and softwar', 'busi', 'dev & design', 'googl', 'larry pag'],
#  ['30 days of buzzword',
#   'brand',
#   'busi',
#   'buzzword',
#   'mobil',
#   'retail',
#   'showroom',
#   'small busi',
#   'startup'],
#  ['world'],
#  ['entertain', 'mlb', 'sport'],
#  ['fashion', 'entertain', 'music', 'urban outfitt', 'vinyl', 'watercool'],
#  ['awkward', 'famili', 'funni', 'holiday', 'photographi', 'watercool'],
#  ['fcc', 'net neutrality ', 'polit', 'protest', 'u.s.', 'world', 'wheeler'],
#  ['colleg',
#   'department of educ',
#   'health & fit',
#   'investig',
#   'polit',
#   'sexual assault',
#   'u.s.',
#   'us govern',
#   'world'],
#  ['apps and softwar',
#   'media',
#   'mobil',
#   'second screen',
#   'social media',
#   'social tv',
#   'televis',
#   'twitter'],
#  ['lifestyl', 'product', 'time manag', 'work & play'],
#  ['apps and softwar', 'jawbon', 'mobil', 'tech'],
#  ['food', 'mad men', 'televis', 'watercool'],
#  ['protests in ferguson', ' missouri ', 'u.s.', 'world'],
#  ['apps and softwar', 'social media', 'vine'],
#  ['apps and softwar',
#   'edward snowden',
#   'gchq',
#   'hack',
#   'privaci',
#   'spi',
#   'surveil',
#   'u.s.',
#   'world',
#   'webcam'],
#  ['cyberattack', 'lastpass', 'target', 'tech', 'u.s.'],
#  ['bit.li', 'busi', 'media'],
#  ['lifestyl', 'polit', 'travel', 'travel & leisur'],
#  ['entertain', 'nfl', 'sport', 'u.s.'],
#  ['data',
#   'data visu',
#   'design',
#   'dev & design',
#   'galleri',
#   'social good',
#   'stem seri',
#   'tech',
#   'u.s.',
#   'world'],
#  ['space', 'googl', 'social good', 'social good summit', 'world'],
#  ['3d-printed gun', '3d print', 'dev & design', 'tech'],
#  ['entertain', 'movi', 'rian johnson', 'star war'],
#  ['gadget',
#   'gift guid',
#   'holidays 2013',
#   'lifestyl',
#   'work and play',
#   'work & play'],
#  ['entertain', 'sport', 'tenni'],
#  ['convers', 'epic fail', 'facebook', 'social media'],
#  ['instagram', 'sunset', 'sunsetwarrior', 'watercool', 'weird'],
#  ['app',
#   'apps and softwar',
#   'busi',
#   'media',
#   'national public radio',
#   'pandora',
#   'podcast',
#   'radio',
#   'stream',
#   'streaming mus',
#   'streaming music servic',
#   'u.s.',
#   'world'],
#  ['apps and softwar', 'day', 'photo app', 'tech', 'wander'],
#  ['economi',
#   'employ',
#   'job hunt',
#   'job search',
#   'job',
#   'lifestyl',
#   'u.s.',
#   'work & play'],
#  ['eric cantor',
#   'house of repres',
#   'polit',
#   'republican',
#   'u.s. house of repres',
#   'u.s.',
#   'world'],
#  ['fertil', 'health & fit', 'reproductive health', 'sperm', 'uk', 'world'],
#  ['busi', 'googl', 'google fib', 'media', 'u.s.'],
#  ['blackberri', 'blackberry z10', 'ebay', 'mobil', 'tech'],
#  ['entertain', 'soccer', 'sport'],
#  ['commun',
#   'entertain',
#   'heat wav',
#   'music',
#   'music monday',
#   'playlist',
#   'spotifi',
#   'climat'],
#  ['parent', 'cute', 'funni', 'video', 'video', 'viral video', 'watercool'],
#  ['advertis',
#   'budweis',
#   'entertain',
#   'facebook',
#   'made for mus',
#   'market',
#   'mobil',
#   'music',
#   'vice media',
#   'video',
#   'video',
#   'youtub'],
#  ['advertis', 'busi', 'foursquar', 'small busi'],
#  ['how to', 'social media', 'tumblr', 'work & play'],
#  ['video', 'video', 'watercool'],
#  ['bulli', 'entertain', 'nfl', 'sport'],
#  ['health & fit', 'lifestyl', 'plastic surgeri'],
#  ['batman',
#   'convers',
#   'photographi',
#   'travel',
#   'travel & leisur',
#   'watercool'],
#  ['bill ny', 'entertain', 'video', 'video', 'watercool'],
#  ['advertis', 'busi', 'market', 'video', 'video', 'viral video'],
#  ['family & par',
#   'kid presid',
#   'mom',
#   'parent',
#   'video',
#   'video',
#   'watercool'],
#  ['funni',
#   'humor',
#   'kim jong-un',
#   'photobomb',
#   'photographi',
#   'viral newsletter s',
#   'watercool'],
#  ['comet', 'space', 'world'],
#  ['mobil', 'mobile world congress', 'samsung galaxy s5', 'tech'],
#  ['apps and softwar', 'dev & design', 'imgur', 'mobil', 'tech'],
#  ['bluetooth',
#   'dev & design',
#   'gadget',
#   'kickstart',
#   'mobil',
#   'tech',
#   'wearable tech'],
#  ['convers', 'oxford dictionari', 'vape', 'vapor', 'watercool'],
#  ['charger',
#   'gadget',
#   'health & fit',
#   'kickstart',
#   'lifestyl',
#   'mobile charg',
#   'newsi',
#   'startup'],
#  ['captain', 'ferri', 'south korea', 'world'],
#  ['gadget', 'mobil', 'qualcomm', 'smartwatch', 'tech'],
#  ['4k',
#   'best buy',
#   'blu-ray',
#   'market',
#   'soni',
#   'tech',
#   'televis',
#   'ultra hd'],
#  ['funni',
#   'internet',
#   'music',
#   'music',
#   'photographi',
#   'theater',
#   'watercool'],
#  ['appl', 'bono', 'entertain', 'iphon', 'music', 'u2'],
#  ['u.s.', 'world'],
#  ['aurora', 'northern light', 'solar storm', 'space', 'space weath', 'world'],
#  ['facebook',
# ...
#  ['boeing 787', 'dev & design', 'gadget', 'tech', 'world'],
#  ['99 problem',
#   'ali graham',
#   'illustr',
#   'jay-z',
#   'photographi',
#   'tumblr',
#   'watercool'],
#  ['ukraine ', 'world'],
#  ['apps and softwar',
#   'citi',
#   'dev & design',
#   'laser',
#   'laser',
#   'map',
#   'world'],
#  ['u.s.', 'world'],
#  ['astronomi', 'meteor show', 'perseid meteor show', 'space', 'world'],
#  ['startup', 'strike', 'travel', 'travel & leisur', 'u.s.', 'world'],
#  ['appl', 'gold iphon', 'iphon', 'iphone 5', 'mobil', 'tech'],
#  ['celeb',
#   'game of thron',
#   'sansa',
#   'televis',
#   'video',
#   'video',
#   'viral video',
#   'watercool'],
#  ['3d print',
#   'braill',
#   "children's book",
#   'dev & design',
#   'family & par',
#   'tech'],
#  ['architectur',
#   'citi',
#   'design',
#   'dev & design',
#   'social good',
#   'green',
#   'u.s.',
#   'world'],
#  ['apps and softwar', 'mashable vine challeng', 'social media', 'vine'],
#  ['entertain', 'movi', 'iron man', 'marvel', 'springbreakit'],
#  ['a la cart', 'cable tv', 'polit', 'senate bil', 'u.s.', 'world'],
#  ['bloomberg', 'busi', 'earn', 'mobil', 'samsung', 'smartphon'],
#  ['imgur', 'javert', 'meme', 'photographi', 'reddit', 'watercool'],
#  ['entertain', 'nba', 'sport'],
#  ['car', 'speed', 'sport', 'sports car', 'tech'],
#  ['astronomi', 'gadget', 'space', 'telescop', 'u.s.', 'world'],
#  ['allen ginsberg',
#   'ben fost',
#   'columbia univers',
#   'convers',
#   'dane dehaan',
#   'daniel radcliff',
#   'elizabeth olsen',
#   'entertain',
#   'movi',
#   'jack huston',
#   'jack kerouac',
#   'jennifer jason leigh',
#   'kill your darl',
#   'michael c hal',
#   'video',
#   'video',
#   'william s. burrough'],
#  ['mer', 'middle east', 'u.s.', 'world'],
#  ['skype', 'middle east', 'world'],
#  ['amazon', 'galaxy s iv', 'mobil', 'samsung', 'samsung galaxy s iii'],
#  ['humor', 'media', 'tumblr', 'watercool', 'yahoo', 'yahoo answ'],
#  ['apps-and-softwar', 'apps and softwar', 'bacon', 'oscar may', 'tech'],
#  ['busi', 'market', 'paypal', 'squar'],
#  ['edward snowden', 'privaci', 'surveil', 'u.s.', 'world'],
#  ['dev & design', 'dna', 'world'],
#  ['busi',
#   'features roundup',
#   'job',
#   'lifestyl',
#   'market',
#   'small busi',
#   'social media',
#   'tech',
#   'travel',
#   'travel & leisur',
#   'twitter',
#   'work & play'],
#  ['bankruptci', 'detroit', 'u.s.', 'world'],
#  ['advertis', 'busi', 'facebook', 'social media'],
#  ['busi',
#   'ceo',
#   'hulu',
#   'media',
#   'netflix',
#   'televis',
#   'video',
#   'video stream'],
#  ['protests in ferguson',
#   ' missouri ',
#   'protest',
#   'st. loui',
#   'u.s.',
#   'world'],
#  ['gadget', 'lenovo', 'tablet', 'tech'],
#  ['advertis', 'busi', 'google chrom', 'spam'],
#  ['30 days of gift',
#   'christmas gift',
#   'gadget',
#   'gift guid',
#   'home',
#   'magic',
#   'magic remot',
#   'remote control',
#   'tech',
#   'travel',
#   'travel & leisur',
#   'work & play'],
#  ['game of thron', 'humor', 'photographi', 'televis', 'watercool'],
#  ['amazon', 'col needham', 'entertain', 'movi', 'imdb', 'televis'],
#  ['apps and softwar', 'comcast', 'netflix', 'tech'],
#  ['advertis', 'busi', 'market', 'super bowl', 'volkswagen'],
#  ['accessori',
#   'case',
#   'edit-samsung-galaxy-s-4',
#   'gadget',
#   'galleri',
#   'home',
#   'lifestyl',
#   'mobil',
#   'samsung',
#   'galaxy s4',
#   'tech',
#   'travel',
#   'travel & leisur',
#   'work & play'],
#  ['polit', 'sport', 'world'],
#  ['apps and softwar',
#   'match',
#   'match.com',
#   'online d',
#   'small busi',
#   'startup',
#   'tech',
#   'work & play'],
#  ['busi', 'googl', 'market', 'privaci', 'world'],
#  ['social media', 'twitter'],
#  ['entertain', 'nba', 'sport', 'video', 'video', 'watercool'],
#  ['discoveri', 'newsi', 'report', 'space', 'world', 'video', 'video'],
#  ['apps and softwar',
#   'candy crush saga',
#   'candy crush soda saga',
#   'entertain',
#   'game',
#   'king',
#   'mobile gam'],
#  ['chernobyl', 'hunt', 'world'],
#  ['appl',
#   'busi',
#   'chart of the day',
#   'gadget',
#   'iphon',
#   'mobil',
#   'samsung',
#   'smartphon'],
#  ['humor', 'instagram', 'photographi', 'twitter', 'watercool'],
#  ['entertain', 'televis', 'the walking dead'],
#  ['advertis', 'appl', 'busi', 'gadget', 'iphon', 'iphone 5c', 'nokia'],
#  ['busi', 'portland', 'startup', 'travel', 'travel & leisur', 'u.s.'],
#  ['bbc', 'cat', 'convers', 'gp', 'watercool', 'world'],
#  ['brandspeak', 'family & par', 'health & fit', 'lifestyl'],
#  ['busi', 'market', 'smart car', 'twitter', "valentine's day"],
#  ['slow mot', 'video', 'video', 'viral video', 'watercool'],
#  ['30 rock',
#   'ben & jerri',
#   'entertain',
#   'entertainment new',
#   'food',
#   'ice cream',
#   'market',
#   'televis'],
#  ['climat', 'earth', 'u.s.', 'world'],
#  ['busi', 'larry ellison', 'oracl'],
#  ['20th century fox',
#   'entertain',
#   'movi',
#   'trailer',
#   'televis',
#   'x-men: days of future past'],
#  ['busi', 'cable televis', 'comcast', 'net neutrality ', 'televis'],
#  ['apps and softwar',
#   'family & par',
#   'galleri',
#   'lifestyl',
#   'sex & lov',
#   'web',
#   'work & play'],
#  ['propos', 'video', 'video', 'vimeo', 'viral video', 'watercool'],
#  ['dev & design',
#   'googl',
#   'street view',
#   'newsi',
#   'tech',
#   'travel',
#   'travel & leisur',
#   'world',
#   'zoo'],
#  ['access', 'blind', 'dev & design', 'social good', 'tech', 'visually impair'],
#  ['app', 'email', 'flickr', 'yahoo'],
#  ['busi', 'market', 'netflix', 'televis'],
#  ['android app',
#   'apps-and-softwar',
#   'apps and softwar',
#   'ios app',
#   'tech',
#   'weekly app roundup',
#   'windows phone app'],
#  ['3d print', 'gadget', 'lix', 'tech'],
#  ['chart of the day', 'mobil', 'tech'],
#  ['convers',
#   'family & par',
#   'femin',
#   'greek lif',
#   'home',
#   'social media',
#   'total frat mov',
#   'twitter',
#   'u.s.',
#   'video',
#   'video',
#   'watercool',
#   'work & play'],
#  ['earthquak', 'geolog', 'los angel', 'quak', 'u.s.', 'world'],
#  ['app',
#   'apps and softwar',
#   'iphon',
#   'mobil',
#   'photographi',
#   'smartphon',
#   'tech'],
#  ['billy eichn',
#   'billy on the street',
#   'emmi',
#   'new york c',
#   'seth mey',
#   'televis',
#   'video',
#   'video',
#   'viral video',
#   'watercool'],
#  ['8 bit', 'comic', 'sunday com', 'watercool'],
#  ['apps and softwar', 'messag', 'mobil', 'tech', 'whatsapp?'],
#  ['advertis', 'busi', 'market'],
#  ['entertain', 'movi'],
#  ['video', 'video', 'viral video', 'watercool'],
#  ['71st golden glob',
#   'entertain',
#   'movi',
#   'golden globe award',
#   'golden glob',
#   'televis'],
#  ['basketbal', 'college sport', 'entertain', 'march mad', 'sport'],
#  ['appl',
#   'apps and softwar',
#   'authentec',
#   'dev & design',
#   'gadget',
#   'iphone 5',
#   'tech',
#   'touch id'],
#  ['tech', 'travel', 'travel & leisur', 'watercool'],
#  ['bb10', 'blackberri', 'blackberry z10', 'busi', 'gadget', 'stock'],
#  ['data plan', 'gadget', 'iphone 5', 'tech', 'wal-mart'],
#  ['lifestyl',
#   'new york c',
#   'television charact',
#   'travel',
#   'travel & leisur',
#   'televis',
#   'u.s.'],
#  ['bashar al-assad', 'polit', 'middle east', 'u.s.', 'world'],
#  ['entertain', 'joan riv', 'melissa riv', 'televis'],
#  ['antonio martin', 'protests in ferguson', ' missouri ', 'u.s.', 'world'],
#  ['halloween',
#   'jimmy fallon',
#   'pumpkin',
#   'the tonight show',
#   'televis',
#   'video',
#   'video',
#   'viral video',
#   'watercool'],
#  ['apps and softwar', 'busi', 'candy crush saga', 'game', 'ipo', 'twitter'],
#  ['fuel cel', 'gadget', 'hover craft', 'tech'],
#  ['health & fit', 'opinion', 'sergey brin', 'social good', 'world'],
#  ['brazil', 'gadget', 'mobil', 'samsung', 'world'],
#  ['entertain', 'heroes reborn', 'nbc', 'televis', 'television critics associ'],
#  ['christma',
#   'gift guid',
#   'holiday',
#   'holidays 2014',
#   'present',
#   'video',
#   'video',
#   'watercool'],
#  ['apps and softwar',
#   'digital rights manag',
#   'entertain',
#   'movi',
#   'flixster',
#   'kickstart',
#   'softwar',
#   'televis',
#   'ultraviolet',
#   'warner bro'],
#  ['cover song',
#   'cover',
#   'ellie gould',
#   'entertain',
#   'justin timberlak',
#   'music'],
#  ['cool', 'watercool'],
#  ['ebola', 'u.s.', 'world'],
#  ['chris evan',
#   'entertain',
#   'movi',
#   'movie review',
#   'toronto international film festiv'],
#  ['busi', 'career advic', 'job', 'mistak', 'negoti', 'salari'],
#  ['advertis',
#   'busi',
#   'market',
#   'net a port',
#   'ptriqu',
#   'shit girls say',
#   'the outnet',
#   'video'],
#  ['architectur', 'design', 'photographi', 'sweden', 'watercool'],
#  ['entertain', 'nba', 'sport'],
#  ['busi', 'startup'],
#  ['hagel', 'polit', 'tim howard', 'world', 'world cup'],
#  ['gadget', 'lifestyl', 'world', 'wristwatch'],
#  ['ashoka mukpo', 'ebola', 'u.s.', 'world'],
#  ['30 days of buzzword', 'advertis', 'busi', 'buzzword', 'market', 'roi'],
#  ['entertain',
#   'game',
#   'mac gam',
#   'pc game',
#   'steam',
#   'steam machin',
#   'steamo',
#   'valve softwar'],
#  ['basketbal', 'gadget', 'sport', 'tech', 'wearable tech'],
#  ['busi', 'mary meek', 'photo shar'],
#  ['amc',
#   'breaking bad',
#   'entertain',
#   'nbc',
#   'nielsen media research',
#   'social tv',
#   'the-voic',
#   'the walking dead',
#   'televis',
#   'twitter'],
#  ['entertain', 'music', 'music video', 'paris hilton', 'unicorn'],
#  ['polit', 'u.s.', 'world'],
#  ['cat', 'funni', 'video', 'video', 'viral video', 'watercool'],
#  ['cdc', 'diseas', 'fda', 'nih', 'smallpox', 'world', 'usa'],
#  ['gadget', 'mobil', 'pebbl', 'smartwatch', 'tech'],
#  ['state depart', 'ukraine ', 'u.s.', 'world', 'youtub'],
#  ['apps and softwar', 'gchat', 'gmail', 'googl', 'mobil', 'tech'],
#  ['apps and softwar', 'ddos attack', 'do', 'hootsuit', 'tech'],
#  ['climat', 'tornado', 'u.s.', 'world', 'vine'],
#  ['comic', 'extralif', 'full width', 'game', 'humor', 'sim citi', 'watercool'],
#  ['amazon', 'busi', 'deliveri', 'fedex', 'market', 'up'],
#  ['angelina joli', 'brad pitt', 'celeb', 'convers', 'entertain'],
#  ['parent', 'family & par', 'genom', 'lifestyl'],
#  ['amazon',
#   'mashread',
#   'interactive map',
#   'lifestyl',
#   'market',
#   'travel',
#   'travel & leisur',
#   "valentine's day"],
#  ['affordable care act',
#   'polit',
#   'glitch',
#   'health & fit',
#   'healthcar',
#   'obamacar',
#   'u.s.',
#   'world'],
#  ['australia',
#   'chris hemsworth',
#   'entertain',
#   'movi',
#   'peopl',
#   'sexiest man al',
#   'thor'],
#  ['china', 'chinese hack', 'googl', 'u.s.', 'world'],
#  ['hacker',
#   'hack',
#   'syrian electronic armi',
#   'the washington post',
#   'u.s.',
#   'world'],
#  ['3d print',
#   'biomedicin',
#   'gadget',
#   'medical technolog',
#   'research',
#   'social good',
#   'stem cel',
#   'tech',
#   'transplant',
#   'u.s.',
#   'world'],
#  ['apps and softwar',
#   'computer system',
#   'convers',
#   'movi',
#   'hacker',
#   'jurassic park',
#   'tech',
#   'unix',
#   'watercool'],
#  ['advertis',
#   'animal right',
#   'brandspeak',
#   'busi',
#   'fur',
#   'lush',
#   '#makefurhistori',
#   'market',
#   'media'],
#  ['sport', 'video', 'video', 'viral video', 'watercool'],
#  ['sport', 'video', 'video', 'watercool'],
#  ['photographi', 'watercool'],
#  ['entertain',
#   'game',
#   'pc game',
#   'steam',
#   'steam machin',
#   'steamo',
#   'valve softwar'],
#  ['dj earworm',
#   'entertain',
#   'music',
#   'video',
#   'video',
#   'viral video',
#   'watercool'],
#  ['masayoshi son',
#   'mobil',
#   'softbank',
#   'sprint',
#   't-mobil',
#   'tech',
#   'verizon',
#   'wireless carri'],
#  ['busi', 'halloween', 'halloween costum', 'market', 'wal-mart'],
#  ['bing',
#   'clip art',
#   'dev and design',
#   'dev & design',
#   'microsoft',
#   'microsoft word',
#   'tech'],
#  ['pumpkin', 'pumpkin', 'u.s.', 'world'],
#  ['android',
#   'apps-and-softwar',
#   'apps and softwar',
#   'flickr',
#   'mobil',
#   'tech'],
#  ['gadget', 'nest', 'nest protect', 'tech'],
#  ['fov', 'parodi', 'video', 'video', 'viral video', 'watercool', 'youtub'],
#  ['middle east', 'israel and gaza', 'mashable must read', 'polit', 'world'],
#  ['abus',
#   'adrian peterson',
#   'entertain',
#   'jonathan dwy',
#   'nfl',
#   'ray ric',
#   'sport'],
#  ['dr. seuss', 'the walking dead', 'video', 'video', 'watercool'],
#  ['israel and gaza',
#   'iron dom',
#   'middle east',
#   'missil',
#   'space',
#   'tech',
#   'world'],
#  ['cable tv',
#   'comcast',
#   'funny or di',
#   'funny video',
#   'hulu',
#   'netflix',
#   'time warn',
#   'televis',
#   'video',
#   'video',
#   'watercool'],
#  ['facebook', 'video', 'video', 'watercool'],
#  ['app permiss',
#   'apps and softwar',
#   'dev & design',
#   'facebook',
#   'login',
#   'mobil',
#   'nike',
#   'tech',
#   'words with friend'],
#  ['disney', 'disney infin', 'entertain', 'movi', 'game'],
#  ['apps and softwar', 'mashable vine challeng', 'social media', 'vine'],
#  ['apps and softwar', 'busi', 'digg', 'google read', 'media'],
#  ['adam lambert', 'entertain', 'music', 'queen', 'televis', 'x factor'],
#  ['android', 'busi', 'googl', 'hugo barra', 'job'],
#  ['biolog', 'medical technolog', 'photographi', 'world', 'x-ray'],
#  ['entertain', 'hemlock grov', 'netflix', 'streaming tv', 'televis'],
#  ['advertis', 'busi', 'retail'],
#  ['apps and softwar',
#   'contributor',
#   'design',
#   'dev & design',
#   'small busi',
#   'softwar',
#   'startup',
#   'tech'],
#  ['bill gat',
#   'job',
#   'microsoft',
#   'parodi',
#   'steve job',
#   'steve jobs movi',
#   'video',
#   'video',
#   'viral video',
#   'watercool',
#   'youtub'],
#  ['app', 'apps and softwar', 'facebook', 'instagram', 'tech'],
#  ['apps and softwar',
#   'hotmail',
#   'microsoft',
#   'outlook.com',
#   'privaci',
#   'secur',
#   'tech'],
#  ['entertain', 'mashable must read', 'nba', 'sport'],
#  ['65th emmy award',
#   'emmi',
#   'entertain',
#   'neil patrick harri',
#   'photographi',
#   'primetime emmi',
#   'televis',
#   'twitter',
#   'video',
#   'watercool'],
#  ['entertain', 'gadget', 'game', 'virtual r'],
#  ['bathroom',
#   'convers',
#   'fart',
#   'health & fit',
#   'home',
#   'poop',
#   'viral newsletter s',
#   'watercool',
#   'weird'],
#  ['google bu',
#   'lawsuit',
#   'polit',
#   'protest',
#   'san francisco-san jos',
#   'tech',
#   'tech shuttl'],
#  ['bebop', 'drone', 'gadget', 'parrot', 'tech'],
#  ['appl', 'busi', 'mobil', 'samsung'],
#  ['bill murray',
#   'funni',
#   'halloween',
#   'humor',
#   'video',
#   'video',
#   'viral video',
#   'watercool'],
#  ['aol', 'busi', 'gathr', 'startup'],
#  ['counterterror', 'islamic st', 'islamist', 'united kingdom', 'world'],
#  ['dev & design',
#   'gadget',
#   'googl',
#   'google glass',
#   'google glass',
#   'mobil',
#   'tech'],
#  ['90', 'convers', 'tax day', 'tax', 'the 90', 'video', 'video', 'watercool'],
#  ['college humor',
#   'comedi',
#   'funni',
#   'sketch comedi',
#   'video',
#   'video',
#   'viral video',
#   'watercool'],
#  ['doma', 'lgbt', 'polit', 'u.s.', 'world'],
#  ['busi',
#   'data',
#   'free',
#   'getti',
#   'getty imag',
#   'media',
#   'photographi',
#   'work & play'],
#  ['nan'],
#  ['beats electron', 'beats by dr', 'bose', 'busi', 'headphon', 'patent'],
#  ['american horror stori',
#   'american horror story: freak show',
#   'entertain',
#   'televis'],
#  ['music', 'video', 'video', 'viral video', 'watercool', 'weird', 'wtf'],
#  ['apps and softwar', 'busi', 'marissa may', 'stamp', 'startup', 'yahoo'],
#  ['comic', 'jerry k', 'march mad', 'sport', 'sunday com', 'watercool'],
#  ['charitable giv',
#   'giving tuesday',
#   'philanthropi',
#   'social good',
#   'u.s.',
#   'world',
#   'volunt'],
#  ['entertain', 'music', 'music monday', 'playlist', 'spotifi'],
#  ['apps and softwar', 'dev & design', 'program', 'startup', 'tech'],
#  ['entertain', 'mark hamil', 'televis', 'the flash'],
#  ['android',
#   'build',
#   'comput',
#   'dev & design',
#   'diy',
#   'kickstart',
#   'program',
#   'robot',
#   'startup',
#   'tech'],
#  ['apps and softwar',
#   'gadget',
#   'lenovo',
#   'mobil',
#   'tablet',
#   'tech',
#   'windows 8.1'],
#  ['apps and softwar', 'entertain', 'movi', 'peanut', 'snoopi', 'vine'],
#  ['advertis',
#   'beer',
#   'bud light',
#   'busi',
#   'super bowl',
#   'superbowl ad',
#   'video',
#   'video',
#   'viral video'],
#  ['protests in ferguson', ' missouri ', 'u.s.', 'world'],
#  ['facebook',
#   'leonardo dicaprio',
#   'madame tussaud',
#   'mark zuckerberg',
#   'rihanna',
#   'san francisco-san jos',
#   'social media',
#   'wax'],
#  ['amazon', 'parent', 'gadget', 'kindle fire hd', 'mobil', 'tablet', 'tech'],
#  ['adam driv',
#   'daniel radcliff',
#   'entertain',
#   'movi',
#   'harry pott',
#   'star war',
#   'star wars episode vii'],
#  ['infograph', 'olymp', 'sport', 'world', 'winter olympics 2014'],
#  ['middle east', 'israel and gaza', 'world'],
#  ['aaron-swartz',
#   'computer fraud and abuse act',
#   'open access',
#   'u.s.',
#   'world'],
#  ['australia', 'convers', 'reddit', 'world', 'wanker'],
#  ['askem', 'busi', 'startup', 'the launchpad'],
#  ['new york c', 'times squar', 'u.s.', 'world'],
#  ...]

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
mlb = MultiLabelBinarizer()
one_hot_topic = mlb.fit_transform(stemmed_topics)

# %%
mlb.classes_
# Out:
# array([' missouri ', '"i love it"', '#1connect', ..., 'zunzuneo', 'zynga',
#        'zz ward'], dtype=object)

# %%
from sklearn.decomposition import LatentDirichletAllocation
lda = LatentDirichletAllocation(n_components=10, max_iter=50, learning_method='batch', n_jobs=-2, verbose=1)

# %%
lda.fit(one_hot_topic)
# Out:
# iteration: 1 of max_iter: 50
# iteration: 2 of max_iter: 50
# iteration: 3 of max_iter: 50
# iteration: 4 of max_iter: 50
# iteration: 5 of max_iter: 50
# iteration: 6 of max_iter: 50
# iteration: 7 of max_iter: 50
# iteration: 8 of max_iter: 50
# iteration: 9 of max_iter: 50
# iteration: 10 of max_iter: 50
# iteration: 11 of max_iter: 50
# iteration: 12 of max_iter: 50
# iteration: 13 of max_iter: 50
# iteration: 14 of max_iter: 50
# iteration: 15 of max_iter: 50
# iteration: 16 of max_iter: 50
# iteration: 17 of max_iter: 50
# iteration: 18 of max_iter: 50
# iteration: 19 of max_iter: 50
# iteration: 20 of max_iter: 50
# iteration: 21 of max_iter: 50
# iteration: 22 of max_iter: 50
# iteration: 23 of max_iter: 50
# iteration: 24 of max_iter: 50
# iteration: 25 of max_iter: 50
# iteration: 26 of max_iter: 50
# iteration: 27 of max_iter: 50
# iteration: 28 of max_iter: 50
# iteration: 29 of max_iter: 50
# iteration: 30 of max_iter: 50
# iteration: 31 of max_iter: 50
# iteration: 32 of max_iter: 50
# iteration: 33 of max_iter: 50
# iteration: 34 of max_iter: 50
# iteration: 35 of max_iter: 50
# iteration: 36 of max_iter: 50
# iteration: 37 of max_iter: 50
# iteration: 38 of max_iter: 50
# iteration: 39 of max_iter: 50
# iteration: 40 of max_iter: 50
# iteration: 41 of max_iter: 50
# iteration: 42 of max_iter: 50
# iteration: 43 of max_iter: 50
# iteration: 44 of max_iter: 50
# iteration: 45 of max_iter: 50
# iteration: 46 of max_iter: 50
# iteration: 47 of max_iter: 50
# iteration: 48 of max_iter: 50
# iteration: 49 of max_iter: 50
# iteration: 50 of max_iter: 50
# LatentDirichletAllocation(max_iter=50, n_jobs=-2, verbose=1)

# %%
a = lda.transform(one_hot_topic)
a.shape
# Out:
# (27643, 10)

# %%
a[0]
# Out:
# array([0.01428571, 0.01428571, 0.01428571, 0.65402923, 0.01428571,
#        0.01428575, 0.01428765, 0.01428571, 0.23168308, 0.01428571])

# %%
topic_type = np.argsort(-a)[:,:1]

# %%
topic_type
# Out:
# array([[3],
#        [7],
#        [4],
#        ...,
#        [5],
#        [1],
#        [2]], dtype=int64)

# %%
typ = pd.DataFrame(data=topic_type)

# %%
# Out:
#    Id  Popularity                                       Page content  \
# 0   0          -1  <html><head><div class="article-info"> <span c...
# 1   1           1  <html><head><div class="article-info"><span cl...
# 2   2           1  <html><head><div class="article-info"><span cl...
# 3   3          -1  <html><head><div class="article-info"><span cl...
# 4   4          -1  <html><head><div class="article-info"><span cl...
#
#     data-channel                                              title  \
# 0          world  NASA's Grand Challenge: Stop Asteroids From De...
# 1           tech  Google's New Open Source Patent Pledge: We Won...
# 2  entertainment  Ballin': 2014 NFL Draft Picks Get to Choose Th...
# 3    watercooler        Cameraperson Fails Deliver Slapstick Laughs
# 4  entertainment  NFL Star Helps Young Fan Prove Friendship With...
#
#                                          raw_content  content_length  \
# 0   There may be killer asteroids headed for Eart...             583
# 1   Google took a stand of sorts against patent-l...             309
# 2   You've spend countless hours training to be a...            1360
# 3       Tired of the same old sports fails and ne...             476
# 4   At 6-foot-5 and 298 pounds, All-Pro NFL star ...            1937
#
#    avg_word_length  topics           author  year  month  day  hour  min  sec  \
# 0         5.214905       3              NaN  2013      6   19    15    4   30
# 1         5.032787       7        christina  2013      3   28    17   40   55
# 2         4.750225       4        sam-laird  2014      5    7    19   15   20
# 3         4.841727       5        sam-laird  2013     10   11     2   26   50
# 4         5.089650       4  connor-finnegan  2014      4   17     3   31   43
#
#    weekends  img_number  link_number  title_length
# 0         0           1           22            60
# 1         0           2           18            74
# 2         0           2           11            68
# 3         0           1           13            43
# 4         0          52           16            61

# %%
new_type = typ.rename(columns={0: 'topics'})
new_type.to_csv('topics.csv')

# %%
new_type
# Out:
#        topics
# 0           3
# 1           7
# 2           4
# 3           5
# 4           4
# ...       ...
# 27638       8
# 27639       0
# 27640       5
# 27641       1
# 27642       2
#
# [27643 rows x 1 columns]
